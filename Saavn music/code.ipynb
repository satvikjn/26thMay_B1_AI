# %%
import requests
from bs4 import BeautifulSoup 
import pandas as pd

# %%
header ={
'Authorization': 'SAPISIDHASH c217a68aff17150cf1c067c1ae212023d6db2c3f',
'DNT': '1',
'X-Goog-AuthUser': '0',
'sec-ch-ua-mobile': '?0',
'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.77 Safari/537.36',
'Content-Type': 'application/x-www-form-urlencoded;charset=UTF-8',
'Accept': '*/*',
}

# %%
ur = requests.get("https://www.jiosaavn.com/featured/international_charts/DjLfyo0wfbk_", headers = header)
ur.status_code
# Out:
# 200

# %%
txt = ur.text

# %%
soup_txt = BeautifulSoup(txt, 'html.parser')

# %%
ed_txt = soup_txt.find_all('ol', {'class' :'o-list-bare u-margin-bottom-none@sm'})[0]

# %%
song_name = [i.text for i in ed_txt.find_all('a', {'class' :'u-color-js-gray'})]

# %%
song_name
# Out:
# ['Butter',
#  'good 4 u',
#  'Levitating (feat. DaBaby)',
#  'Peaches',
#  'Leave The Door Open',
#  'Save Your Tears (Remix)',
#  'Kiss Me More',
#  'Astronaut In The Ocean',
#  'deja vu',
#  'Yonaguni',
#  'MONTERO (Call Me By Your Name)',
#  'WITHOUT YOU (Miley Cyrus Remix)',
#  'Forever After All',
#  'RAPSTAR',
#  'Blinding Lights',
#  'Hats Off',
#  'drivers license',
#  'Beautiful Mistakes',
#  'traitor',
#  'Late At Night',
#  'Voice of the Heroes',
#  'Best Friend (feat. Doja Cat)',
#  'Heartbreak Anniversary',
#  'Heat Waves',
#  'Calling My Phone',
#  'favorite crime',
#  'Lost Cause',
#  'happier',
#  'Up',
#  '24Kgoldn Mood',
#  '2040',
#  'EVERY CHANCE I GET',
#  'telepatía',
#  'How It Feels',
#  'brutal',
#  'Wockesha',
#  'Wants and Needs',
#  'Famous Friends',
#  'pov',
#  'Gone',
#  'Beat Box 3',
#  "my ex's best friend",
#  'Still Runnin',
#  'Track Star',
#  'What You Know Bout Love',
#  'Who I Want',
#  'Back In Blood (feat. Lil Durk)',
#  'Time Today',
# ...

# %%
len(song_name
   )
# Out:
# 50

# %%
artist = [i.text for i in ed_txt.find_all('p', {"class":"u-centi u-ellipsis u-color-js-gray-alt-light u-margin-right@sm u-margin-right-none@lg"})]

# %%
len(artist)
# Out:
# 50

# %%
duration = [i.text for i in ed_txt.find_all('span',{'class':'o-snippet__action-init u-centi'})][1::2]

# %%
len(duration)
# Out:
# 50

# %%
link = ['jiosaavn.com' + i.get('href') for i in ed_txt.find_all('a', {'class' :'u-color-js-gray'})]

# %%
len(link)
# Out:
# 50

# %%
df = pd.DataFrame({'Song':song_name, 'Artist':artist, 'Duration':duration, 'Link':link})

# %%
df.index += 1

# %%
print('Top 50 Songs are')
df
# Out:
# Top 50 Songs are
#                                Song  \
# 1                            Butter
# 2                          good 4 u
# 3         Levitating (feat. DaBaby)
# 4                           Peaches
# 5               Leave The Door Open
# 6           Save Your Tears (Remix)
# 7                      Kiss Me More
# 8            Astronaut In The Ocean
# 9                           deja vu
# 10                         Yonaguni
# 11   MONTERO (Call Me By Your Name)
# 12  WITHOUT YOU (Miley Cyrus Remix)
# 13                Forever After All
# 14                          RAPSTAR
# 15                  Blinding Lights
# 16                         Hats Off
# 17                  drivers license
# 18               Beautiful Mistakes
# 19                          traitor
# 20                    Late At Night
# 21              Voice of the Heroes
# 22     Best Friend (feat. Doja Cat)
# 23           Heartbreak Anniversary
# 24                       Heat Waves
# ...
