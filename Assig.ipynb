# %%
import pandas as pd

# %%
import warnings
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Test 2.csv")

# %%
df
# Out:
#       Id   Open Date        City  City Group Type  P1   P2   P3   P4  P5  ...  \
# 0      0  07/17/1999    İstanbul  Big Cities   IL   4  5.0  4.0  4.0   2  ...
# 1      1  02/14/2008      Ankara  Big Cities   FC   4  5.0  4.0  4.0   1  ...
# 2      2  03/09/2013  Diyarbakır       Other   IL   2  4.0  2.0  5.0   2  ...
# 3      3  02/02/2012       Tokat       Other   IL   6  4.5  6.0  6.0   4  ...
# 4      4  05/09/2009   Gaziantep       Other   IL   3  4.0  3.0  4.0   2  ...
# ..   ...         ...         ...         ...  ...  ..  ...  ...  ...  ..  ...
# 132  132  06/25/2008     Trabzon       Other   FC   2  3.0  3.0  5.0   4  ...
# 133  133  10/12/2006       İzmir  Big Cities   FC   4  5.0  4.0  4.0   2  ...
# 134  134  07/08/2006     Kayseri       Other   FC   3  4.0  4.0  4.0   2  ...
# 135  135  10/29/2010    İstanbul  Big Cities   FC   4  5.0  4.0  5.0   2  ...
# 136  136  09/01/2009    İstanbul  Big Cities   FC   4  5.0  3.0  5.0   2  ...
#
#      P29  P30  P31  P32  P33  P34  P35  P36  P37    revenue
# 0    3.0    5    3    4    5    5    4    3    4  5653753.0
# 1    3.0    0    0    0    0    0    0    0    0  6923131.0
# 2    3.0    0    0    0    0    0    0    0    0  2055379.0
# 3    7.5   25   12   10    6   18   12   12    6  2675511.0
# 4    3.0    5    1    3    2    3    4    3    3  4316715.0
# ..   ...  ...  ...  ...  ...  ...  ...  ...  ...        ...
# 132  3.0    0    0    0    0    0    0    0    0  5787594.0
# 133  3.0    0    0    0    0    0    0    0    0  9262754.0
# 134  3.0    0    0    0    0    0    0    0    0  2544857.0
# 135  3.0    0    0    0    0    0    0    0    0  7217634.0
# 136  3.0    0    0    0    0    0    0    0    0  6363241.0
#
# [137 rows x 43 columns]

# %%
def jecrc(x):
    if x == "Other":
        x = 0
    else:
        x = 1
    return x

# %%
df["City Group"].value_counts()
# Out:
# Big Cities    78
# Other         59
# Name: City Group, dtype: int64

# %%
df["City Group"] = df["City Group"].apply(jecrc)

# %%
del df["Id"]

# %%
df
# Out:
#       Open Date        City  City Group Type  P1   P2   P3   P4  P5  P6  ...  \
# 0    07/17/1999    İstanbul           1   IL   4  5.0  4.0  4.0   2   2  ...
# 1    02/14/2008      Ankara           1   FC   4  5.0  4.0  4.0   1   2  ...
# 2    03/09/2013  Diyarbakır           0   IL   2  4.0  2.0  5.0   2   3  ...
# 3    02/02/2012       Tokat           0   IL   6  4.5  6.0  6.0   4   4  ...
# 4    05/09/2009   Gaziantep           0   IL   3  4.0  3.0  4.0   2   2  ...
# ..          ...         ...         ...  ...  ..  ...  ...  ...  ..  ..  ...
# 132  06/25/2008     Trabzon           0   FC   2  3.0  3.0  5.0   4   2  ...
# 133  10/12/2006       İzmir           1   FC   4  5.0  4.0  4.0   2   3  ...
# 134  07/08/2006     Kayseri           0   FC   3  4.0  4.0  4.0   2   3  ...
# 135  10/29/2010    İstanbul           1   FC   4  5.0  4.0  5.0   2   2  ...
# 136  09/01/2009    İstanbul           1   FC   4  5.0  3.0  5.0   2   2  ...
#
#      P29  P30  P31  P32  P33  P34  P35  P36  P37    revenue
# 0    3.0    5    3    4    5    5    4    3    4  5653753.0
# 1    3.0    0    0    0    0    0    0    0    0  6923131.0
# 2    3.0    0    0    0    0    0    0    0    0  2055379.0
# 3    7.5   25   12   10    6   18   12   12    6  2675511.0
# 4    3.0    5    1    3    2    3    4    3    3  4316715.0
# ..   ...  ...  ...  ...  ...  ...  ...  ...  ...        ...
# 132  3.0    0    0    0    0    0    0    0    0  5787594.0
# 133  3.0    0    0    0    0    0    0    0    0  9262754.0
# 134  3.0    0    0    0    0    0    0    0    0  2544857.0
# 135  3.0    0    0    0    0    0    0    0    0  7217634.0
# 136  3.0    0    0    0    0    0    0    0    0  6363241.0
#
# [137 rows x 42 columns]

# %%
df["Type"].value_counts()
# Out:
# FC    76
# IL    60
# DT     1
# Name: Type, dtype: int64

# %%
import seaborn as sns

# %%
df.columns
# Out:
# Index(['Id', 'Open Date', 'City', 'City Group', 'Type', 'P1', 'P2', 'P3', 'P4',
#        'P5', 'P6', 'P7', 'P8', 'P9', 'P10', 'P11', 'P12', 'P13', 'P14', 'P15',
#        'P16', 'P17', 'P18', 'P19', 'P20', 'P21', 'P22', 'P23', 'P24', 'P25',
#        'P26', 'P27', 'P28', 'P29', 'P30', 'P31', 'P32', 'P33', 'P34', 'P35',
#        'P36', 'P37', 'revenue'],
#       dtype='object')

# %%
for i in df.columns[:-1]:
    plt.scatter(df['revenue'],df[i])
    plt.xlabel('revenue')
    plt.ylabel(i)
    plt.title(i + 'vs Price')
    plt.grid()
    plt.show()

# %%
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-40-73edc048c06b> in <module>
# ----> 1 from sklearn.model_selection import train_test_split
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\__init__.py in <module>
#      80     from . import _distributor_init  # noqa: F401
#      81     from . import __check_build  # noqa: F401
# ---> 82     from .base import clone
#      83     from .utils._show_versions import show_versions
#      84
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py in <module>
#      15 from . import __version__
#      16 from ._config import get_config
# ---> 17 from .utils import _IS_32BIT
#      18 from .utils._tags import (
#      19     _DEFAULT_TAGS,
#
# ModuleNotFoundError: No module named 'sklearn.utils'
